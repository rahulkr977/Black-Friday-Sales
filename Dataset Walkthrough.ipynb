# %%
import pandas as pd

# %%
df=pd.read_csv("business-financia data.csv")

# %%
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6190     BDCQ.SF8RSCA  2021.09     382.195        NaN      F  Dollars
# 6191     BDCQ.SF8RSCA  2021.12     397.184        NaN      F  Dollars
# 6192     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Series_reference']
# Out:
# 0       BDCQ.SF1AA2CA
# 1       BDCQ.SF1AA2CA
# 2       BDCQ.SF1AA2CA
# 3       BDCQ.SF1AA2CA
# 4       BDCQ.SF1AA2CA
#             ...
# 6190     BDCQ.SF8RSCA
# 6191     BDCQ.SF8RSCA
# 6192     BDCQ.SF8RSCA
# 6193     BDCQ.SF8RSCA
# 6194     BDCQ.SF8RSCA
# Name: Series_reference, Length: 6195, dtype: object

# %%
for i in df.columns:
    print(df[i][0])
# Out:
# BDCQ.SF1AA2CA
# 2016.06
# 1116.386
# nan
# F
# Dollars
# 6
# Business Data Collection - BDC
# Industry by financial variable (NZSIOC Level 2)
# Sales (operating income)
# Forestry and Logging
# Current prices
# Unadjusted
# nan

# %%
df(Head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 df(Head)
#
# NameError: name 'Head' is not defined

# %%
df.isnull()
# Out:
#       Series_reference  Period  Data_value  Suppressed  STATUS  UNITS  \
# 0                False   False       False        True   False  False
# 1                False   False       False        True   False  False
# 2                False   False       False        True   False  False
# 3                False   False       False        True   False  False
# 4                False   False       False        True   False  False
# ...                ...     ...         ...         ...     ...    ...
# 6190             False   False       False        True   False  False
# 6191             False   False       False        True   False  False
# 6192             False   False       False        True   False  False
# 6193             False   False       False        True   False  False
# 6194             False   False       False        True   False  False
#
#       Magnitude  Subject  Group  Series_title_1  Series_title_2  \
# ...

# %%
df.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value           475
# Suppressed          6180
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      6195
# dtype: int64

# %%
kf=df.drop(['Suppressed','Series_title_5'],axis=1)

# %%
kf
# Out:
#      Series_reference   Period  Data_value STATUS    UNITS  Magnitude  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386      F  Dollars          6
# 1       BDCQ.SF1AA2CA  2016.09    1070.874      F  Dollars          6
# 2       BDCQ.SF1AA2CA  2016.12    1054.408      F  Dollars          6
# 3       BDCQ.SF1AA2CA  2017.03    1010.665      F  Dollars          6
# 4       BDCQ.SF1AA2CA  2017.06    1233.700      F  Dollars          6
# ...               ...      ...         ...    ...      ...        ...
# 6190     BDCQ.SF8RSCA  2021.09     382.195      F  Dollars          6
# 6191     BDCQ.SF8RSCA  2021.12     397.184      F  Dollars          6
# 6192     BDCQ.SF8RSCA  2022.03     493.945      F  Dollars          6
# 6193     BDCQ.SF8RSCA  2022.06     579.955      R  Dollars          6
# 6194     BDCQ.SF8RSCA  2022.09     609.161      F  Dollars          6
#
#                              Subject  \
# 0     Business Data Collection - BDC
# 1     Business Data Collection - BDC
# ...

# %%
pf.isnull().sum()
# Out:
# Series_reference    0
# Period              0
# Data_value          0
# STATUS              0
# UNITS               0
# Magnitude           0
# Subject             0
# Group               0
# Series_title_1      0
# Series_title_2      0
# Series_title_3      0
# Series_title_4      0
# dtype: int64

# %%
pf=kf.dropna()

# %%
pf
# Out:
#      Series_reference   Period  Data_value STATUS    UNITS  Magnitude  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386      F  Dollars          6
# 1       BDCQ.SF1AA2CA  2016.09    1070.874      F  Dollars          6
# 2       BDCQ.SF1AA2CA  2016.12    1054.408      F  Dollars          6
# 3       BDCQ.SF1AA2CA  2017.03    1010.665      F  Dollars          6
# 4       BDCQ.SF1AA2CA  2017.06    1233.700      F  Dollars          6
# ...               ...      ...         ...    ...      ...        ...
# 6190     BDCQ.SF8RSCA  2021.09     382.195      F  Dollars          6
# 6191     BDCQ.SF8RSCA  2021.12     397.184      F  Dollars          6
# 6192     BDCQ.SF8RSCA  2022.03     493.945      F  Dollars          6
# 6193     BDCQ.SF8RSCA  2022.06     579.955      R  Dollars          6
# 6194     BDCQ.SF8RSCA  2022.09     609.161      F  Dollars          6
#
#                              Subject  \
# 0     Business Data Collection - BDC
# 1     Business Data Collection - BDC
# ...

# %%
#Finding Average rating

# %%
df['Data_value']
# Out:
# 0       1116.386
# 1       1070.874
# 2       1054.408
# 3       1010.665
# 4       1233.700
#           ...
# 6190     382.195
# 6191     397.184
# 6192     493.945
# 6193     579.955
# 6194     609.161
# Name: Data_value, Length: 6195, dtype: float64

# %%
(sum(df['Data_value']))
# Out:
# nan

# %%
int(sum(df['Period']))
# Out:
# 12508286

# %%
str(int(sum(df['Period']))/6194)[:7]
# Out:
# '2019.41'

# %%
p=0
for i in df['Period']:
    p += i
    
s=int(p)   
print(p)
# Out:
# 12508286.759999357

# %%
## Q2.How many apps are there ith rating 5 ?

# %%
df['period']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'period'
#
# The above exception was the direct cause of the following exception:
#
# ...
